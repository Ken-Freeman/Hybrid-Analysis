# %% [markdown]
# # Pull data from Hybrid-Analysis using their API and make a model to predict whether traffic is malicious or no

# %% [markdown]
# ### conda install requests

# %%
import requests
import json

# %% [markdown]
# ### Set headers for the API request

# %%
parameters = {
    "api-key": "s3vwbiju16f29800tnrm7m1o11d8af609qpen4wg539481160qg3q7rh3c96aabc",
    "accept-encoding" : "gzip",
    "user-agent" : "Falcon Sandbox"
}

# %% [markdown]
# ### Pull from feed

# %%
response = requests.get("https://www.hybrid-analysis.com/feed?json", headers=parameters)
## log out the return code and any headers - not required for this problem but useful
print("response code: ", response.status_code, "content length is ", len(response.content))
print("headers: ", json.dumps(response.headers.__dict__, sort_keys=True, indent=4))
# Out:
# response code:  200 content length is  2585265
# headers:  {
#     "_store": {
#         "access-control-allow-origin": [
#             "Access-Control-Allow-Origin",
#             "*"
#         ],
#         "cache-control": [
#             "Cache-Control",
#             "max-age=0, private, must-revalidate, max-age=2592000"
#         ],
#         "cf-cache-status": [
#             "CF-Cache-Status",
#             "DYNAMIC"
#         ],
#         "cf-ray": [
#             "CF-RAY",
#             "63bf960dca7ac7c9-DEN"
#         ],
#         "cf-request-id": [
#             "cf-request-id",
#             "094b9c1ca10000c7c9313fc000000001"
#         ],
#         "connection": [
#             "Connection",
#             "keep-alive"
#         ],
#         "content-encoding": [
#             "Content-Encoding",
#             "gzip"
#         ],
#         "content-security-policy": [
#             "Content-Security-Policy",
#             "default-src 'none'; connect-src 'self' *.twitter.com; script-src 'self' *.google.com *.gstatic.com *.google-analytics.com *.twitter.com *.twimg.com cdn.inspectlet.com frontend.id-visitors.com 'unsafe-inline'; font-src 'self' data: fonts.googleapis.com; child-src 'self' data: *.google.com *.gstatic.com *.twitter.com; img-src 'self' data: *.gstatic.com *.google.com *.google-analytics.com stats.g.doubleclick.net *.twitter.com *.twimg.com *.paypalobjects.com cartodb-basemaps-a.global.ssl.fastly.net cartodb-basemaps-b.global.ssl.fastly.net cartodb-basemaps-c.global.ssl.fastly.net; style-src 'self' *.google.com *.twitter.com *.twimg.com 'unsafe-inline'; object-src 'self'; frame-ancestors 'none'"
#         ],
#         "content-type": [
#             "Content-Type",
#             "application/json"
#         ],
#         "date": [
#             "Date",
#             "Wed, 07 Apr 2021 01:47:07 GMT"
#         ],
#         "expect-ct": [
#             "Expect-CT",
#             "max-age=604800, report-uri=\"https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct\""
#         ],
#         "expires": [
#             "Expires",
#             "Fri, 07 May 2021 01:47:07 GMT"
#         ],
#         "server": [
#             "Server",
#             "cloudflare"
#         ],
#         "set-cookie": [
#             "Set-Cookie",
#             "__cfduid=d10a531aad427424659692153ed021b0d1617760027; expires=Fri, 07-May-21 01:47:07 GMT; path=/; domain=.hybrid-analysis.com; HttpOnly; SameSite=Lax; Secure, id=5q913bi4m6afpo1ku96u2vhnud; path=/; HttpOnly"
#         ],
#         "strict-transport-security": [
#             "Strict-Transport-Security",
#             "max-age=31536000; includeSubdomains"
#         ],
#         "transfer-encoding": [
#             "Transfer-Encoding",
#             "chunked"
#         ],
#         "x-content-type-options": [
#             "X-Content-Type-Options",
#             "nosniff"
#         ],
#         "x-frame-options": [
#             "x-frame-options",
#             "SAMEORIGIN, SAMEORIGIN"
#         ],
#         "x-xss-protection": [
#             "X-XSS-Protection",
#             "1; mode=block"
#         ]
#     }
# }

# %%
json_response = response.json()
datasets = json_response['data']
print(datasets)
# Out:
# [{'md5': '7d9fe40f0a42ac5a98530b561c491cbf', 'sha1': '2731eee5b52eae162583fdbed440041de5b530eb', 'sha256': '533a49585421cfd5c3cfbea055a8de7867b9423037aa0bb26a33b25aa9950e2a', 'isunknown': True, 'isinteresting': False, 'analysis_start_time': '2021-04-07 01:37:11', 'threatscore': 58, 'threatlevel': 2, 'threatlevel_human': 'malicious', 'submitname': 'https://www.unitednationsfoundation.org/', 'isurlanalysis': True, 'domains': ['www.unitednationsfoundation.org'], 'hosts': ['69.48.252.158'], 'hosts_geo': [{'ip': '69.48.252.158', 'lat': '30.3649', 'lon': '-97.6827', 'cc': 'USA'}], 'compromised_hosts': ['69.48.252.158'], 'environmentId': '120', 'environmentDescription': 'Windows 7 64 bit', 'sharedanalysis': False, 'isreliable': True, 'reporturl': '/sample/533a49585421cfd5c3cfbea055a8de7867b9423037aa0bb26a33b25aa9950e2a/606d0cc56a9a5b19d23233f4', 'process_list': [{'uid': '00066025-00003228', 'name': 'rundll32.exe', 'normalizedpath': '%WINDIR%\\System32\\rundll32.exe', 'commandline': '"%WINDIR%\\System32\\ieframe.dll",OpenURL C:\\533a49585421cfd5c3cfbea055a8de7867b9423037aa0bb26a33b25aa9950e2a.url', 'sha256': '405f03534be8b45185695f68deb47d4daf04dcd6df9d351ca6831d3721b1efc4'}, {'uid': '00066180-00002116', 'parentuid': '00066025-00003228', 'name': 'iexplore.exe', 'normalizedpath': '%PROGRAMFILES%\\Internet Explorer\\iexplore.exe', 'commandline': 'https://www.unitednationsfoundation.org/', 'sha256': 'c00b9f2b32828341a9185ae2be1a0649c9f503f0b5cccebc75be4c2f8c596530'}, {'uid': '00066212-00003604', 'parentuid': '00066180-00002116', 'name': 'iexplore.exe', 'normalizedpath': '%PROGRAMFILES%\\(x86)\\Internet Explorer\\iexplore.exe', 'commandline': 'SCODEF:2116 CREDAT:275457 /prefetch:2', 'sha256': '072041fa70bb351030c516e1b6f7f21d15495da158f3890826ba5b978af8900e'}], 'extracted_files': [{'name': 'urlblockindex_1_.bin', 'file_path': '', 'file_size': '16', 'sha1': 'e4f30e49120657d37267c0162fd4a08934800c69', 'sha256': '775853600060162c4b4e5f883f9fd5a278e61c471b3ee1826396b6d129499aa7', 'md5': 'fa518e3dfae8ca3a0e495460fd60c791', 'type': 'data', 'type_tags': ['data'], 'threatlevel': 0, 'threatlevel_readable': 'no specific threat', 'av_matched': '0', 'av_total': '79'}, {'name': '0P4TC7JB.txt', 'file_path': '%APPDATA%\\Microsoft\\Windows\\Cookies\\0P4TC7JB.txt', 'file_size': '110', 'sha1': '8bc9a90d602538b511fceee3a69237b7b7f590ae', 'sha256': '56ed719fcda5262ead101171d2056021c26161f8fcaa7509aebd6e4fbdc694f3', 'md5': 'd52850998c9472403afec856e63699e5', 'type': 'ASCII text', 'type_tags': ['text'], 'threatlevel': 0, 'threatlevel_readable': 'no specific threat', 'targetname': 'iexplore.exe', 'targetpid': 2116}, {'name': '1HSSSDRS.txt', 'file_path': '%APPDATA%\\Microsoft\\Windows\\Cookies\\1HSSSDRS.txt', 'file_size': '172', 'sha1': 'ed4e09508852f3ed20a9dc7d9058106e9a203eb4', 'sha256': '15ff61df64f2d370daffca9de4e2d828860a2fb835afffec4cf5f7849cb61884', 'md5': '5be966584f917b3c6ed45ee4a17e7710', 'type': 'ASCII text', 'type_tags': ['text'], 'threatlevel': 0, 'threatlevel_readable': 'no specific threat', 'targetname': 'iexplore.exe', 'targetpid': 2116}, {'name': '6E22BMV1.txt', 'file_path': '%APPDATA%\\Microsoft\\Windows\\Cookies\\6E22BMV1.txt', 'file_size': '541', 'sha1': '8e4f33aedc22f63f8bdb2083cfd588269c26dae1', 'sha256': '1d9d99e67878c776a215626b22c72daa4f74109ea95059f95afad9cf32bdb61b', 'md5': '104735b7dc65791ec346790364b08a45', 'type': 'ASCII text', 'type_tags': ['text'], 'threatlevel': 0, 'threatlevel_readable': 'no specific threat', 'targetname': 'iexplore.exe', 'targetpid': 3604}, {'name': 'E69IEKVU.txt', 'file_path': '%APPDATA%\\Microsoft\\Windows\\Cookies\\E69IEKVU.txt', 'file_size': '250', 'sha1': 'f913bbc0d90cc072c8cd5a4777d8b29dd0d1050a', 'sha256': '3150cbe93dc4e1652b9eaae4ae45bdf914c38966102306e28cbfd8a863ea9bc6', 'md5': '0deab7fe28bbf0fdb653ad24555d23b2', 'type': 'ASCII text', 'type_tags': ['text'], 'threatlevel': 0, 'threatlevel_readable': 'no specific threat', 'targetname': 'iexplore.exe', 'targetpid': 2116}, {'name': 'FQQEMYXU.txt', 'file_pa ...

# %%
json_response = response.json()
datasets = json_response['data']
print (len(datasets))
print ("first one is of type ", type(datasets[0]))
#print ("first one is ", datasets[0])
print (datasets[0].keys())
print()
#print ("first one is ", json.dumps(datasets[0], sort_keys=True, indent=4))
print ("is interesting: ", datasets[0].get("isinteresting"), " threatscore:", datasets[0].get("threatscore"), "reporturl: ", datasets[0].get("reporturl"), " sha256:", datasets[0].get("sha256"))
# Out:
# 173
# first one is of type  <class 'dict'>
# dict_keys(['md5', 'sha1', 'sha256', 'isunknown', 'isinteresting', 'analysis_start_time', 'threatscore', 'threatlevel', 'threatlevel_human', 'submitname', 'isurlanalysis', 'domains', 'hosts', 'hosts_geo', 'compromised_hosts', 'environmentId', 'environmentDescription', 'sharedanalysis', 'isreliable', 'reporturl', 'process_list', 'extracted_files', 'ssdeep'])
#
# is interesting:  False  threatscore: 58 reporturl:  /sample/533a49585421cfd5c3cfbea055a8de7867b9423037aa0bb26a33b25aa9950e2a/606d0cc56a9a5b19d23233f4  sha256: 533a49585421cfd5c3cfbea055a8de7867b9423037aa0bb26a33b25aa9950e2a

# %% [markdown]
# ### This for loop is just practice for a similar for loop later on. Not used in model

# %%
for aThing in datasets:
# is interesting:  False  threatscore: 17  reporturl: /sample/34d6641ef41c0cedfd1ee09feb8cf19b35ffb3528a587b43f124de1fd492271b/606cf682718b6635a810117e  sha256: 34d6641ef41c0cedfd1ee09feb8cf19b35ffb3528a587b43f124de1fd492271b
# is interesting:  False  threatscore: 63  reporturl: /sample/f6e54b1fbe19c0c362484f9caa24258f60947ecc293f0c91f6635103fc5c7c43/606cf62d02e73232d2060ed8  sha256: f6e54b1fbe19c0c362484f9caa24258f60947ecc293f0c91f6635103fc5c7c43
# is interesting:  False  threatscore: 63  reporturl: /sample/2651135d5251de4407b000eccf1898ee84ec269304e4ecc26ed128cb86b6cf33/606cf6130ef503645c090af9  sha256: 2651135d5251de4407b000eccf1898ee84ec269304e4ecc26ed128cb86b6cf33
# is interesting:  True  threatscore: 90  reporturl: /sample/fbb7ec49018504f22388e937f8e14c44007f3ac57ff11eb14fec2c2f9af036cd/606cf603b1d48d664878fbe8  sha256: fbb7ec49018504f22388e937f8e14c44007f3ac57ff11eb14fec2c2f9af036cd
# is interesting:  False  threatscore: 12  reporturl: /sample/f58ee2a7fd212674c4cf8c5c8891b440d5f58de406adfe570d6499195e10c23c/606cf6013cdd2d350c26e5b4  sha256: f58ee2a7fd212674c4cf8c5c8891b440d5f58de406adfe570d6499195e10c23c
# is interesting:  False  threatscore: 0  reporturl: /sample/7500a3b4afa5e3db14b5f2d9e15d9b4e8496bd053d60aff4a3e5b4c703530d52/606cf603eebd75382f53ce18  sha256: 7500a3b4afa5e3db14b5f2d9e15d9b4e8496bd053d60aff4a3e5b4c703530d52
# is interesting:  True  threatscore: 85  reporturl: /sample/7158004689d24effc49b64eb1224f2420e6b197d52f47c56041eeff97ac3e847/606cf6031b282a76b86bb2d4  sha256: 7158004689d24effc49b64eb1224f2420e6b197d52f47c56041eeff97ac3e847
# is interesting:  False  threatscore: 58  reporturl: /sample/c96b2d71db8a90ca04808df7b68494d92e6d85b1aee6dbc7e32da25f8075e60f/606cf5fe6101f31837720825  sha256: c96b2d71db8a90ca04808df7b68494d92e6d85b1aee6dbc7e32da25f8075e60f
# is interesting:  False  threatscore: 63  reporturl: /sample/f003cfe699536cfb19b0f0516bc09187a365404d1bb2673c9d543cc42240c3da/606cf5de60209413856a5a54  sha256: f003cfe699536cfb19b0f0516bc09187a365404d1bb2673c9d543cc42240c3da
# is interesting:  False  threatscore: 22  reporturl: /sample/974ffa9baa600bf54aa988b74261293636785590f0e248e79774832ba31fc15e/606cf5af2dfcae4c027c7169  sha256: 974ffa9baa600bf54aa988b74261293636785590f0e248e79774832ba31fc15e

# %% [markdown]
# ### Format the data into a dataframe

# %%
import pandas as pd
df = pd.DataFrame(datasets)
df
# Out:
#                                   md5  \
# 0    7d9fe40f0a42ac5a98530b561c491cbf
# 1    71cf320948188336f7a0f15cb4b5fe2c
# 2    b24caa17ef80a1c1a343239a6297b02c
# 3    5f3851de951281b209c6eaa89779187d
# 4    793ba4a9fc612a8af84783080650a860
# ..                                ...
# 168  f0f38dd785f42f18e73b627116b2d1e2
# 169  6d073528761de40addbbc22e50fd9123
# 170  da5dd0dac5d31787f383b5a1a8ae0bdf
# 171  6840acd70f213c6c8ef2734b33b30cad
# 172  45df0b3ee42b68baf70414f88dc13b96
#
#                                          sha1  \
# 0    2731eee5b52eae162583fdbed440041de5b530eb
# 1    12ec316473a0e1d20f0a7647fef0324481be8946
# 2    c4951482d75dddd33c5bad409425bf40f7f4fe04
# 3    ac55a2b233070701b3bc2973b6384a5393b50d9a
# 4    184e94864916263b7a451f87f135dd22031c3084
# ..                                        ...
# 168  951a74317038c787e58e6dd56d7da96a0b8c49ad
# 169  d3c11f4563020b2d0ec9c0abc85955667dff49e9
# 170  bf26abb7590b194011c811df968728f8eb3688ea
# 171  b0336f83c5c1871df9c92d4d13b18212f2cd2559
# 172  d3aa38c318cba96da2e9bd751030c15eacb8b3be
#
#                                                 sha256  isunknown  \
# 0    533a49585421cfd5c3cfbea055a8de7867b9423037aa0b...       True
# 1    e38dc7c0409ef9e731c1682156c7a72deffd252200292a...      False
# 2    c3b4f511aa9e5a2d985232629fb62fd40a1b6e547feaca...      False
# 3    67f0dfa92c2f6aae85dcc77494f65db5ec5b945620a33f...       True
# 4    ddedfbc89b682198a3b5580282370f4fd18e882166f6d3...       True
# ..                                                 ...        ...
# 168  7500a3b4afa5e3db14b5f2d9e15d9b4e8496bd053d60af...       True
# 169  7158004689d24effc49b64eb1224f2420e6b197d52f47c...       True
# 170  c96b2d71db8a90ca04808df7b68494d92e6d85b1aee6db...       True
# 171  f003cfe699536cfb19b0f0516bc09187a365404d1bb267...       True
# 172  974ffa9baa600bf54aa988b74261293636785590f0e248...       True
#
#      isinteresting  analysis_start_time  threatscore  threatlevel  \
# 0            False  2021-04-07 01:37:11           58            2
# 1            False  2021-04-07 01:34:59            0            0
# 2            False  2021-04-07 01:34:00           35            0
# 3            False  2021-04-07 01:33:21           30            1
# 4             True  2021-04-07 01:32:10           85            2
# ..             ...                  ...          ...          ...
# 168          False  2021-04-07 00:00:07            0            0
# 169           True  2021-04-07 00:00:07           85            2
# 170          False  2021-04-07 00:00:00           58            2
# 171          False  2021-04-06 23:59:27           63            2
# 172          False  2021-04-06 23:58:48           22            2
#
#       threatlevel_human                                         submitname  \
# 0             malicious           https://www.unitednationsfoundation.org/
# 1    no specific threat  https://play.google.com/store/apps/details?id=...
# 2    no specific threat                                  http://p4api.net/
# 3            suspicious  https://storage.googleapis.com/fghhjyguyu/akes...
# 4             malicious                        1617759121_w7x32_pafish.exe
# ..                  ...                                                ...
# 168  no specific threat  https://google.com/search?q=Y2Q1MTBhZTI4YmYwMT...
# 169           malicious                              1617753602_pafish.exe
# 170           malicious  https://imaxmovies.site/en/movie/748853/in-the...
# 171           malicious  https://imaxmovies.site/en/movie/460465/mortal...
# 172           malicious                           6bzq-homescapes-hack.pdf
#
#      ...       tags      size  \
# 0    ...        NaN       NaN
# 1    ...        NaN       NaN
# 2    ...        NaN       NaN
# 3    ...        NaN       NaN
# 4    ...  [evasive]  105386.0
# ..   ...        ...       ...
# 168  ...        NaN       NaN
# 169  ...  [evasive]  105386.0
# 170  ...        NaN       NaN
# 171  ...        NaN       NaN
# 172  ...        NaN  114209.0
#
#                                                   type vxfamily  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4    PE32 executable (console) Intel 80386 (strippe...      NaN
# ..                                                 ...      ...
# 168                                                NaN      NaN
# 169  PE32 executable (console) Intel 80386 (strippe...      NaN
# 170                                                NaN      NaN
# 171                                                NaN      NaN
# 172                          PDF document, version 1.3      NaN
#
#     et_alerts_total et_alerts_real_total  \
# 0               NaN                  NaN
# 1               NaN                  NaN
# 2               NaN                  NaN
# 3               NaN                  NaN
# 4               NaN                  NaN
# ..              ...                  ...
# 168             NaN                  NaN
# 169             NaN                  NaN
# 170             NaN                  NaN
# 171            11.0                 11.0
# 172             NaN                  NaN
#
#                                              et_alerts  domains_capped  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 168                                                NaN             NaN
# 169                                                NaN             NaN
# 170                                                NaN             NaN
# 171  [{'srcip': '66.45.227.171', 'destport': '49163...             NaN
# 172                                                NaN             NaN
#
#      hosts_capped public_references
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
# ..            ...               ...
# 168           NaN               NaN
# 169           NaN               NaN
# 170           NaN               NaN
# 171           NaN               NaN
# 172           NaN               NaN
#
# [173 rows x 36 columns]

# %% [markdown]
# ### Look at the reporturl column to see how we need to split it up so we can put the values in a for loop to pull each individual report

# %%
df["reporturl"]
# Out:
# 0      /sample/533a49585421cfd5c3cfbea055a8de7867b942...
# 1      /sample/e38dc7c0409ef9e731c1682156c7a72deffd25...
# 2      /sample/c3b4f511aa9e5a2d985232629fb62fd40a1b6e...
# 3      /sample/67f0dfa92c2f6aae85dcc77494f65db5ec5b94...
# 4      /sample/ddedfbc89b682198a3b5580282370f4fd18e88...
#                              ...
# 168    /sample/7500a3b4afa5e3db14b5f2d9e15d9b4e8496bd...
# 169    /sample/7158004689d24effc49b64eb1224f2420e6b19...
# 170    /sample/c96b2d71db8a90ca04808df7b68494d92e6d85...
# 171    /sample/f003cfe699536cfb19b0f0516bc09187a36540...
# 172    /sample/974ffa9baa600bf54aa988b742612936367855...
# Name: reporturl, Length: 173, dtype: object

# %% [markdown]
# ### Split the report url to seperate out jobid

# %%
#Filter out /sample/ from reporturl column
df["jobid"]=df["reporturl"].str.split("/", expand=True)[3]
list(df)
# Out:
# ['md5',
#  'sha1',
#  'sha256',
#  'isunknown',
#  'isinteresting',
#  'analysis_start_time',
#  'threatscore',
#  'threatlevel',
#  'threatlevel_human',
#  'submitname',
#  'isurlanalysis',
#  'domains',
#  'hosts',
#  'hosts_geo',
#  'compromised_hosts',
#  'environmentId',
#  'environmentDescription',
#  'sharedanalysis',
#  'isreliable',
#  'reporturl',
#  'process_list',
#  'extracted_files',
#  'ssdeep',
#  'avdetect',
#  'vt_detect',
#  'ms_detect',
#  'tags',
#  'size',
#  'type',
#  'vxfamily',
#  'et_alerts_total',
#  'et_alerts_real_total',
#  'et_alerts',
#  'domains_capped',
#  'hosts_capped',
#  'public_references',
#  'jobid']

# %% [markdown]
# ### Combine url with job id so we can insert into for loop to pull all the matching reports from the feed.

# %%
df["url"]= "https://www.hybrid-analysis.com/api/v2/report/"+df["jobid"]+"/summary"
df["url"]
# Out:
# 0      https://www.hybrid-analysis.com/api/v2/report/...
# 1      https://www.hybrid-analysis.com/api/v2/report/...
# 2      https://www.hybrid-analysis.com/api/v2/report/...
# 3      https://www.hybrid-analysis.com/api/v2/report/...
# 4      https://www.hybrid-analysis.com/api/v2/report/...
#                              ...
# 168    https://www.hybrid-analysis.com/api/v2/report/...
# 169    https://www.hybrid-analysis.com/api/v2/report/...
# 170    https://www.hybrid-analysis.com/api/v2/report/...
# 171    https://www.hybrid-analysis.com/api/v2/report/...
# 172    https://www.hybrid-analysis.com/api/v2/report/...
# Name: url, Length: 173, dtype: object

# %% [markdown]
# ### DO NOT USE THIS ONE: Use api to pull report summary data

# %%
#for index, row in df.iterrows():
    ## log out the return code and any headers - not required for this problem but useful
    #print(row["url"])
    #response = requests.get(row["url"], headers=parameters)
    #print("response code: ", response.status_code, "content length is ", len(response.content))
    #print("headers: ", json.dumps(response.headers.__dict__, sort_keys=True, indent=4))
    #json_response = response.json()
    #report = json_response['data']
    #print(json_response)
    
    #df.at[index,"summary"] = json_response

# %% [markdown]
# ### This call puts the json data and puts it into a new "summary" column

# %%
def get_summary(row):
    #print(row)
    response = requests.get(row["url"], headers=parameters)
    print("response code: ", response.status_code, "content length is ", len(response.content))
    #print("headers: ", json.dumps(response.headers.__dict__, sort_keys=True, indent=4))
    json_response = response.json()
    #report = json_response['data']
    #print(json_response)
    
    return json_response
    
df["summary"] = df.apply(get_summary, axis = 1)
# Out:
# response code:  200 content length is  22157
# response code:  200 content length is  11647
# response code:  200 content length is  32240
# response code:  200 content length is  29097
# response code:  200 content length is  6891
# response code:  200 content length is  6861
# response code:  200 content length is  11577
# response code:  200 content length is  33353
# response code:  200 content length is  6891
# response code:  200 content length is  9948
# response code:  200 content length is  3658
# response code:  200 content length is  4222
# response code:  200 content length is  1412
# response code:  200 content length is  1871
# response code:  200 content length is  1728
# response code:  200 content length is  20748
# response code:  200 content length is  30718
# response code:  200 content length is  2382
# response code:  200 content length is  20755
# response code:  200 content length is  6891
# response code:  200 content length is  6861
# response code:  200 content length is  12870
# response code:  200 content length is  14790
# response code:  200 content length is  14656
# response code:  200 content length is  7832
# response code:  200 content length is  1753
# response code:  200 content length is  32413
# response code:  200 content length is  32812
# response code:  200 content length is  32182
# response code:  200 content length is  32554
# response code:  200 content length is  1804
# response code:  200 content length is  33115
# response code:  200 content length is  7741
# response code:  200 content length is  6871
# response code:  200 content length is  11577
# response code:  200 content length is  126579
# response code:  200 content length is  3082
# response code:  200 content length is  29746
# response code:  200 content length is  26534
# response code:  200 content length is  5297
# response code:  200 content length is  6975
# response code:  200 content length is  24275
# response code:  200 content length is  34626
# response code:  200 content length is  32192
# response code:  200 content length is  11361
# response code:  200 content length is  6092
# response code:  200 content length is  29793
# response code:  200 content length is  6901
# response code:  200 content length is  6871
# response code:  200 content length is  23408
# response code:  200 content length is  32069
# response code:  200 content length is  21657
# response code:  200 content length is  24170
# response code:  200 content length is  2262
# response code:  200 content length is  31706
# response code:  200 content length is  31581
# response code:  200 content length is  30526
# response code:  200 content length is  31734
# response code:  200 content length is  6901
# response code:  200 content length is  30912
# response code:  200 content length is  6870
# response code:  200 content length is  31663
# response code:  200 content length is  31697
# response code:  200 content length is  31530
# response code:  200 content length is  31610
# response code:  200 content length is  31509
# response code:  200 content length is  27779
# response code:  200 content length is  31549
# response code:  200 content length is  31553
# response code:  200 content length is  35666
# response code:  200 content length is  25958
# response code:  200 content length is  29962
# response code:  200 content length is  6871
# response code:  200 content length is  6901
# response code:  200 content length is  26919
# response code:  200 content length is  7669
# response code:  200 content length is  1367
# response code:  200 content length is  1343
# response code:  200 content length is  25518
# response code:  200 content length is  33448
# response code:  200 content length is  32736
# response code:  200 content length is  9913
# response code:  200 content length is  32298
# response code:  200 content length is  26604
# response code:  200 content length is  6871
# response code:  200 content length is  29905
# response code:  200 content length is  7644
# response code:  200 content length is  32427
# response code:  200 content length is  30214
# response code:  200 content length is  35551
# response code:  200 content length is  31356
# response code:  200 content length is  10454
# response code:  200 content length is  1678
# response code:  200 content length is  30941
# response code:  200 content length is  3475
# response code:  200 content length is  29590
# response code:  200 content length is  26586
# response code:  200 content length is  26785
# response code:  200 content length is  11269
# response code:  200 content length is  12023
# response code:  200 content length is  3008
# response code:  200 content length is  14373
# response code:  200 content length is  28632
# response code:  200 content length is  17171
# response code:  200 content length is  29335
# response code:  200 content length is  7644
# response code:  200 content length is  7218
# response code:  200 content length is  28064
# response code:  200 content length is  30736
# response code:  200 content length is  31048
# response code:  200 content length is  33788
# response code:  200 content length is  33335
# response code:  200 content length is  23519
# response code:  200 content length is  31140
# response code:  200 content length is  6901
# response code:  200 content length is  30133
# response code:  200 content length is  6871
# response code:  200 content length is  1394
# response code:  200 content length is  31625
# response code:  200 content length is  32824
# response code:  200 content length is  3025
# response code:  200 content length is  30516
# response code:  200 content length is  31125
# response code:  200 content length is  5641
# response code:  200 content length is  33586
# response code:  200 content length is  27333
# response code:  200 content length is  7219
# response code:  200 content length is  7644
# response code:  200 content length is  12510
# response code:  200 content length is  9944
# response code:  200 content length is  25037
# response code:  200 content length is  25288
# response code:  200 content length is  34085
# response code:  200 content length is  7614
# response code:  200 content length is  5966
# response code:  200 content length is  3956
# response code:  200 content length is  5973
# response code:  200 content length is  26690
# response code:  200 content length is  32792
# response code:  200 content length is  7613
# response code:  200 content length is  6901
# response code:  200 content length is  11217
# response code:  200 content length is  21761
# response code:  200 content length is  36031
# response code:  200 content length is  14137
# response code:  200 content length is  14814
# response code:  200 content length is  8910
# response code:  200 content length is  33096
# response code:  200 content length is  26962
# response code:  200 content length is  7614
# response code:  200 content length is  7644
# response code:  200 content length is  29930
# response code:  200 content length is  12149
# response code:  200 content length is  35587
# response code:  200 content length is  13368
# response code:  200 content length is  34226
# response code:  200 content length is  19800
# response code:  200 content length is  30963
# response code:  200 content length is  26125
# response code:  200 content length is  15749
# response code:  200 content length is  30275
# response code:  200 content length is  13726
# response code:  200 content length is  14679
# response code:  200 content length is  11966
# response code:  200 content length is  28105
# response code:  200 content length is  27819
# response code:  200 content length is  7644
# response code:  200 content length is  11295
# response code:  200 content length is  11217
# response code:  200 content length is  6871
# response code:  200 content length is  28724
# response code:  200 content length is  27788
# response code:  200 content length is  12397

# %% [markdown]
# ### Make sure it worked and added the new summary column

# %%
df["summary"]
# Out:
# 0      {'job_id': '606d0cc56a9a5b19d23233f4', 'enviro...
# 1      {'job_id': '606d0c3fec752238c0177f5d', 'enviro...
# 2      {'job_id': '606d0c0667e2b33f0c3e6105', 'enviro...
# 3      {'job_id': '606d0bde7a86c91b47459625', 'enviro...
# 4      {'job_id': '606d0b92fafc502a39187984', 'enviro...
#                              ...
# 168    {'job_id': '606cf603eebd75382f53ce18', 'enviro...
# 169    {'job_id': '606cf6031b282a76b86bb2d4', 'enviro...
# 170    {'job_id': '606cf5fe6101f31837720825', 'enviro...
# 171    {'job_id': '606cf5de60209413856a5a54', 'enviro...
# 172    {'job_id': '606cf5af2dfcae4c027c7169', 'enviro...
# Name: summary, Length: 173, dtype: object

# %% [markdown]
# ### Just checking the summary column type

# %%
print(type(df["summary"]))
print(df["summary"].dtypes)
# Out:
# <class 'pandas.core.series.Series'>
# object

# %% [markdown]
# ### This makes sure no failed reports are included. Aka if we run out of daily requests those aren't added into the dataframe. The block below shows the length of each summary.

# %%
df['sum_len'] = df['summary'].str.len()
print(df['sum_len'])
# Out:
# 0      41
# 1      41
# 2      41
# 3      41
# 4      41
#        ..
# 168    41
# 169    41
# 170    41
# 171    41
# 172    41
# Name: sum_len, Length: 173, dtype: int64

# %% [markdown]
# ### This block gets rid of all the summary's that didn't come through. their length is less than 2

# %%
df = df[df.sum_len > 2]
print(df['sum_len'])
# Out:
# 0      41
# 1      41
# 2      41
# 3      41
# 4      41
#        ..
# 168    41
# 169    41
# 170    41
# 171    41
# 172    41
# Name: sum_len, Length: 173, dtype: int64

# %% [markdown]
# ### Create function to make a new row counting the number of mitre attacks

# %%
#for index, row in df.iterrows():
    # log out the return code and any headers - not required for this problem but useful
    #print(len(row["summary"]["mitre_attcks"]))
    
def get_num_mitre_attcks(row):
    return len(row["summary"]["mitre_attcks"])

    
df["num_mitre_attcks"] = df.apply(get_num_mitre_attcks, axis = 1)
print(df['num_mitre_attcks'])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4      14
#        ..
# 168     0
# 169    14
# 170     4
# 171     4
# 172     5
# Name: num_mitre_attcks, Length: 173, dtype: int64

# %% [markdown]
# # Model Building
# ### Import needed packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


# %matplotlib inline
plt.style.use('ggplot')
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Make a copy of df. We can only access so many pulls in one day from the api so it is imperitive to work "offline" to keep testing

# %%
df2 = df.copy()

# %% [markdown]
# ### Make the 'isinteresting' column a binary

# %%
df2 = df2.reset_index()
np.isnan(df2.any()) #and gets False
np.isfinite(df2.all()) #and gets True
df2
# Out:
#      index                               md5  \
# 0        0  7d9fe40f0a42ac5a98530b561c491cbf
# 1        1  71cf320948188336f7a0f15cb4b5fe2c
# 2        2  b24caa17ef80a1c1a343239a6297b02c
# 3        3  5f3851de951281b209c6eaa89779187d
# 4        4  793ba4a9fc612a8af84783080650a860
# ..     ...                               ...
# 168    168  f0f38dd785f42f18e73b627116b2d1e2
# 169    169  6d073528761de40addbbc22e50fd9123
# 170    170  da5dd0dac5d31787f383b5a1a8ae0bdf
# 171    171  6840acd70f213c6c8ef2734b33b30cad
# 172    172  45df0b3ee42b68baf70414f88dc13b96
#
#                                          sha1  \
# 0    2731eee5b52eae162583fdbed440041de5b530eb
# 1    12ec316473a0e1d20f0a7647fef0324481be8946
# 2    c4951482d75dddd33c5bad409425bf40f7f4fe04
# 3    ac55a2b233070701b3bc2973b6384a5393b50d9a
# 4    184e94864916263b7a451f87f135dd22031c3084
# ..                                        ...
# 168  951a74317038c787e58e6dd56d7da96a0b8c49ad
# 169  d3c11f4563020b2d0ec9c0abc85955667dff49e9
# 170  bf26abb7590b194011c811df968728f8eb3688ea
# 171  b0336f83c5c1871df9c92d4d13b18212f2cd2559
# 172  d3aa38c318cba96da2e9bd751030c15eacb8b3be
#
#                                                 sha256  isunknown  \
# 0    533a49585421cfd5c3cfbea055a8de7867b9423037aa0b...       True
# 1    e38dc7c0409ef9e731c1682156c7a72deffd252200292a...      False
# 2    c3b4f511aa9e5a2d985232629fb62fd40a1b6e547feaca...      False
# 3    67f0dfa92c2f6aae85dcc77494f65db5ec5b945620a33f...       True
# 4    ddedfbc89b682198a3b5580282370f4fd18e882166f6d3...       True
# ..                                                 ...        ...
# 168  7500a3b4afa5e3db14b5f2d9e15d9b4e8496bd053d60af...       True
# 169  7158004689d24effc49b64eb1224f2420e6b197d52f47c...       True
# 170  c96b2d71db8a90ca04808df7b68494d92e6d85b1aee6db...       True
# 171  f003cfe699536cfb19b0f0516bc09187a365404d1bb267...       True
# 172  974ffa9baa600bf54aa988b74261293636785590f0e248...       True
#
#      isinteresting  analysis_start_time  threatscore  threatlevel  \
# 0            False  2021-04-07 01:37:11           58            2
# 1            False  2021-04-07 01:34:59            0            0
# 2            False  2021-04-07 01:34:00           35            0
# 3            False  2021-04-07 01:33:21           30            1
# 4             True  2021-04-07 01:32:10           85            2
# ..             ...                  ...          ...          ...
# 168          False  2021-04-07 00:00:07            0            0
# 169           True  2021-04-07 00:00:07           85            2
# 170          False  2021-04-07 00:00:00           58            2
# 171          False  2021-04-06 23:59:27           63            2
# 172          False  2021-04-06 23:58:48           22            2
#
#       threatlevel_human  ... et_alerts_real_total  \
# 0             malicious  ...                  NaN
# 1    no specific threat  ...                  NaN
# 2    no specific threat  ...                  NaN
# 3            suspicious  ...                  NaN
# 4             malicious  ...                  NaN
# ..                  ...  ...                  ...
# 168  no specific threat  ...                  NaN
# 169           malicious  ...                  NaN
# 170           malicious  ...                  NaN
# 171           malicious  ...                 11.0
# 172           malicious  ...                  NaN
#
#                                              et_alerts domains_capped  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 168                                                NaN            NaN
# 169                                                NaN            NaN
# 170                                                NaN            NaN
# 171  [{'srcip': '66.45.227.171', 'destport': '49163...            NaN
# 172                                                NaN            NaN
#
#     hosts_capped public_references                     jobid  \
# 0            NaN               NaN  606d0cc56a9a5b19d23233f4
# 1            NaN               NaN  606d0c3fec752238c0177f5d
# 2            NaN               NaN  606d0c0667e2b33f0c3e6105
# 3            NaN               NaN  606d0bde7a86c91b47459625
# 4            NaN               NaN  606d0b92fafc502a39187984
# ..           ...               ...                       ...
# 168          NaN               NaN  606cf603eebd75382f53ce18
# 169          NaN               NaN  606cf6031b282a76b86bb2d4
# 170          NaN               NaN  606cf5fe6101f31837720825
# 171          NaN               NaN  606cf5de60209413856a5a54
# 172          NaN               NaN  606cf5af2dfcae4c027c7169
#
#                                                    url  \
# 0    https://www.hybrid-analysis.com/api/v2/report/...
# 1    https://www.hybrid-analysis.com/api/v2/report/...
# 2    https://www.hybrid-analysis.com/api/v2/report/...
# 3    https://www.hybrid-analysis.com/api/v2/report/...
# 4    https://www.hybrid-analysis.com/api/v2/report/...
# ..                                                 ...
# 168  https://www.hybrid-analysis.com/api/v2/report/...
# 169  https://www.hybrid-analysis.com/api/v2/report/...
# 170  https://www.hybrid-analysis.com/api/v2/report/...
# 171  https://www.hybrid-analysis.com/api/v2/report/...
# 172  https://www.hybrid-analysis.com/api/v2/report/...
#
#                                                summary  sum_len  \
# 0    {'job_id': '606d0cc56a9a5b19d23233f4', 'enviro...       41
# 1    {'job_id': '606d0c3fec752238c0177f5d', 'enviro...       41
# 2    {'job_id': '606d0c0667e2b33f0c3e6105', 'enviro...       41
# 3    {'job_id': '606d0bde7a86c91b47459625', 'enviro...       41
# 4    {'job_id': '606d0b92fafc502a39187984', 'enviro...       41
# ..                                                 ...      ...
# 168  {'job_id': '606cf603eebd75382f53ce18', 'enviro...       41
# 169  {'job_id': '606cf6031b282a76b86bb2d4', 'enviro...       41
# 170  {'job_id': '606cf5fe6101f31837720825', 'enviro...       41
# 171  {'job_id': '606cf5de60209413856a5a54', 'enviro...       41
# 172  {'job_id': '606cf5af2dfcae4c027c7169', 'enviro...       41
#
#      num_mitre_attcks
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                  14
# ..                ...
# 168                 0
# 169                14
# 170                 4
# 171                 4
# 172                 5
#
# [173 rows x 42 columns]

# %% [markdown]
# ### Check how many interesting rows there are

# %%
df2["isinteresting_binary"] = df2["isinteresting"].astype(int)

Total = df2['isinteresting_binary'].sum()
print (Total)
# Out:
# 31

# %% [markdown]
# ### Try making nan values 0

# %%
def clean_dataset(df2):
    assert isinstance(df2, pd.DataFrame), "df needs to be a pd.DataFrame"
    df2.dropna(inplace=True)
    indices_to_keep = ~df2.isin([np.nan, np.inf, -np.inf]).any(1)
    return df2[indices_to_keep].astype(np.float64)

# %% [markdown]
# ### Add input variables and split the testing data on a 70/30 split

# %%
X=df2[['threatscore', 'threatlevel', 'num_mitre_attcks']]  # Features
y=df2['isinteresting_binary']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %% [markdown]
# ### Random Forest model. Create a classifier and fit on training data

# %%
from sklearn.ensemble import RandomForestClassifier

cla=RandomForestClassifier(n_estimators=100)

cla.fit(X_train,y_train)

y_pred=cla.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9615384615384616

# %%
from sklearn.metrics import average_precision_score

average_precision = average_precision_score(y_test, y_pred)

print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average precision-recall score: 0.85
